#
#            z2        v2        x3  ...      z499  v499      x500      y500  \
# 293 -0.794118  0.998495  0.618486  ... -0.001908   0.0  0.641085  0.484224
# 294 -0.590785  0.998625  0.618277  ... -0.001745   0.0  0.642716  0.485946
# 295 -0.600279  0.998736  0.617971  ... -0.002513   0.0  0.644807  0.486782
# 296 -0.564804  0.998848  0.617928  ... -0.002672   0.0  0.644391  0.487584
# 297 -0.604902  0.998948  0.618076  ... -0.002956   0.0  0.645325  0.491918
# ..        ...       ...       ...  ...       ...   ...       ...       ...
# 790 -0.614767  0.998349  0.474463  ... -0.022974   0.0  0.497251  0.543712
# 791 -0.606288  0.998350  0.474330  ... -0.023483   0.0  0.497799  0.543943
# 792 -0.609596  0.998319  0.474565  ... -0.023776   0.0  0.501131  0.538314
# 793 -0.621427  0.998358  0.484015  ... -0.022351   0.0  0.510236  0.535559
# 794 -0.641799  0.998378  0.495019  ... -0.020967   0.0  0.519811  0.530756
#
#          z500  v500      x501      y501      z501  v501
# 293  0.017450   0.0  0.646013  0.478508  0.017822   0.0
# 294  0.017700   0.0  0.647692  0.479836  0.018154   0.0
# 295  0.017255   0.0  0.649818  0.480953  0.017726   0.0
# 296  0.017076   0.0  0.649449  0.481815  0.017531   0.0
# 297  0.015803   0.0  0.650681  0.484490  0.016330   0.0
# ..        ...   ...       ...       ...       ...   ...
# 790 -0.049446   0.0  0.503955  0.532318 -0.052895   0.0
# 791 -0.051145   0.0  0.504325  0.533328 -0.054697   0.0
# 792 -0.052498   0.0  0.507664  0.527748 -0.056189   0.0
# 793 -0.046597   0.0  0.517070  0.524616 -0.049855   0.0
# 794 -0.039931   0.0  0.526419  0.519394 -0.042706   0.0
#
# [502 rows x 2005 columns]

# %%
X = df.drop('class', axis=1)
y = df['class']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1234)

# %%
y_test
# Out:
# 1212        Angry
# 1053        Angry
# 1159        Angry
# 281         Happy
# 878     Victories
#           ...
# 155         Happy
# 470           Sad
# 725           Sad
# 685           Sad
# 356           Sad
# Name: class, Length: 382, dtype: object

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model
# Out:
# /Users/hwan/Documents/ml/Analysis_System/.venv/lib/python3.12/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Angry', 'Angry', 'Angry', 'Happy', 'Victories', 'Angry', 'Sad',
#        'Angry', 'Victories', 'Sad', 'Happy', 'Angry', 'Angry',
#        'Victories', 'Sad', 'Sad', 'Angry', 'Happy', 'Victories', 'Happy',
#        'Sad', 'Victories', 'Sad', 'Victories', 'Angry', 'Angry', 'Sad',
#        'Sad', 'Happy', 'Sad', 'Sad', 'Sad', 'Sad', 'Happy', 'Happy',
#        'Sad', 'Angry', 'Sad', 'Angry', 'Sad', 'Sad', 'Angry', 'Sad',
#        'Happy', 'Victories', 'Angry', 'Angry', 'Victories', 'Angry',
#        'Happy', 'Sad', 'Victories', 'Angry', 'Victories', 'Sad', 'Angry',
#        'Victories', 'Sad', 'Sad', 'Angry', 'Angry', 'Angry', 'Sad', 'Sad',
#        'Happy', 'Angry', 'Happy', 'Happy', 'Angry', 'Angry', 'Angry',
#        'Happy', 'Victories', 'Angry', 'Victories', 'Happy', 'Sad', 'Sad',
#        'Angry', 'Sad', 'Angry', 'Happy', 'Happy', 'Victories', 'Sad',
#        'Happy', 'Angry', 'Sad', 'Sad', 'Sad', 'Angry', 'Happy', 'Sad',
#        'Happy', 'Sad', 'Angry', 'Angry', 'Victories', 'Sad', 'Sad',
#        'Happy', 'Sad', 'Angry', 'Sad', 'Sad', 'Sad', 'Happy', 'Happy',
#        'Victories', 'Happy', 'Angry', 'Angry', 'Sad', 'Sad', 'Sad', 'Sad',
#        'Angry', 'Sad', 'Happy', 'Sad', 'Happy', 'Victories', 'Angry',
#        'Happy', 'Happy', 'Angry', 'Angry', 'Happy', 'Angry', 'Sad', 'Sad',
#        'Sad', 'Happy', 'Victories', 'Sad', 'Happy', 'Happy', 'Angry',
#        'Sad', 'Victories', 'Sad', 'Victories', 'Sad', 'Sad', 'Sad', 'Sad',
#        'Sad', 'Victories', 'Sad', 'Happy', 'Angry', 'Angry', 'Angry',
#        'Angry', 'Happy', 'Victories', 'Sad', 'Happy', 'Sad', 'Victories',
#        'Sad', 'Angry', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Angry', 'Sad',
#        'Sad', 'Sad', 'Angry', 'Angry', 'Sad', 'Sad', 'Sad', 'Victories',
#        'Sad', 'Victories', 'Victories', 'Sad', 'Happy', 'Angry', 'Angry',
#        'Angry', 'Angry', 'Victories', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad',
#        'Sad', 'Angry', 'Sad', 'Happy', 'Sad', 'Happy', 'Angry', 'Angry',
#        'Happy', 'Victories', 'Sad', 'Sad', 'Happy', 'Happy', 'Happy',
#        'Sad', 'Sad', 'Victories', 'Sad', 'Sad', 'Sad', 'Victories',
#        'Angry', 'Sad', 'Happy', 'Happy', 'Happy', 'Sad', 'Sad',
#        'Victories', 'Sad', 'Victories', 'Sad', 'Angry', 'Sad', 'Happy',
#        'Happy', 'Sad', 'Sad', 'Sad', 'Sad', 'Victories', 'Happy', 'Happy',
#        'Victories', 'Happy', 'Angry', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Sad', 'Happy', 'Angry', 'Sad', 'Happy', 'Angry', 'Happy', 'Happy',
#        'Angry', 'Angry', 'Happy', 'Sad', 'Sad', 'Sad', 'Victories',
#        'Victories', 'Angry', 'Victories', 'Sad', 'Victories', 'Angry',
#        'Sad', 'Victories', 'Sad', 'Sad', 'Sad', 'Victories', 'Sad',
#        'Angry', 'Sad', 'Victories', 'Victories', 'Angry', 'Sad', 'Happy',
#        'Happy', 'Angry', 'Angry', 'Sad', 'Sad', 'Angry', 'Sad', 'Sad',
#        'Angry', 'Sad', 'Happy', 'Angry', 'Happy', 'Sad', 'Angry', 'Sad',
#        'Happy', 'Victories', 'Angry', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Happy', 'Sad', 'Sad', 'Sad', 'Victories', 'Sad', 'Angry', 'Sad',
#        'Happy', 'Victories', 'Happy', 'Sad', 'Sad', 'Happy', 'Angry',
#        'Angry', 'Angry', 'Happy', 'Sad', 'Angry', 'Happy', 'Sad', 'Angry',
#        'Happy', 'Angry', 'Victories', 'Sad', 'Sad', 'Sad', 'Happy',
#        'Happy', 'Victories', 'Sad', 'Sad', 'Happy', 'Angry', 'Victories',
#        'Sad', 'Angry', 'Sad', 'Sad', 'Sad', 'Victories', 'Angry', 'Angry',
#        'Happy', 'Sad', 'Angry', 'Happy', 'Sad', 'Sad', 'Sad', 'Happy',
#        'Sad', 'Victories', 'Angry', 'Sad', 'Sad', 'Sad', 'Angry',
#        'Victories', 'Sad', 'Sad', 'Sad', 'Happy', 'Angry', 'Happy',
#        'Angry', 'Sad', 'Angry', 'Sad', 'Angry', 'Victories', 'Victories',
#        'Sad', 'Sad', 'Happy', 'Sad', 'Sad', 'Sad', 'Sad'], dtype='<U9')

# %%
y_test
# Out:
# 1212        Angry
# 1053        Angry
# 1159        Angry
# 281         Happy
# 878     Victories
#           ...
# 155         Happy
# 470           Sad
# 725           Sad
# 685           Sad
# 356           Sad
# Name: class, Length: 382, dtype: object

# %%
from sklearn.metrics import accuracy_score
import pickle

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 0.9973821989528796
# rc 1.0
# rf 1.0
# gb 1.0

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Angry', 'Angry', 'Angry', 'Happy', 'Victories', 'Angry', 'Sad',
#        'Angry', 'Victories', 'Sad', 'Happy', 'Angry', 'Angry',
#        'Victories', 'Sad', 'Sad', 'Angry', 'Happy', 'Victories', 'Happy',
#        'Sad', 'Victories', 'Sad', 'Victories', 'Angry', 'Angry', 'Sad',
#        'Sad', 'Happy', 'Sad', 'Sad', 'Sad', 'Sad', 'Happy', 'Happy',
#        'Sad', 'Angry', 'Sad', 'Angry', 'Sad', 'Sad', 'Angry', 'Sad',
#        'Happy', 'Victories', 'Angry', 'Angry', 'Victories', 'Angry',
#        'Happy', 'Sad', 'Victories', 'Angry', 'Victories', 'Sad', 'Angry',
#        'Victories', 'Sad', 'Sad', 'Angry', 'Angry', 'Angry', 'Sad', 'Sad',
#        'Happy', 'Angry', 'Happy', 'Happy', 'Angry', 'Angry', 'Angry',
#        'Happy', 'Victories', 'Angry', 'Victories', 'Happy', 'Sad', 'Sad',
#        'Angry', 'Sad', 'Angry', 'Happy', 'Happy', 'Victories', 'Sad',
#        'Happy', 'Angry', 'Sad', 'Sad', 'Sad', 'Angry', 'Happy', 'Sad',
#        'Happy', 'Sad', 'Angry', 'Angry', 'Victories', 'Sad', 'Sad',
#        'Happy', 'Sad', 'Angry', 'Sad', 'Sad', 'Sad', 'Happy', 'Happy',
#        'Victories', 'Happy', 'Angry', 'Angry', 'Sad', 'Sad', 'Sad', 'Sad',
#        'Angry', 'Sad', 'Happy', 'Sad', 'Happy', 'Victories', 'Angry',
#        'Happy', 'Happy', 'Angry', 'Angry', 'Happy', 'Angry', 'Sad', 'Sad',
#        'Sad', 'Happy', 'Victories', 'Sad', 'Happy', 'Happy', 'Angry',
#        'Sad', 'Victories', 'Sad', 'Victories', 'Sad', 'Sad', 'Sad', 'Sad',
#        'Sad', 'Victories', 'Sad', 'Happy', 'Angry', 'Angry', 'Angry',
#        'Angry', 'Happy', 'Victories', 'Sad', 'Happy', 'Sad', 'Victories',
#        'Sad', 'Angry', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad', 'Angry', 'Sad',
#        'Sad', 'Sad', 'Angry', 'Angry', 'Sad', 'Sad', 'Sad', 'Victories',
#        'Sad', 'Victories', 'Victories', 'Sad', 'Happy', 'Angry', 'Angry',
#        'Angry', 'Angry', 'Victories', 'Sad', 'Sad', 'Sad', 'Sad', 'Sad',
#        'Sad', 'Angry', 'Sad', 'Happy', 'Sad', 'Happy', 'Angry', 'Angry',
#        'Happy', 'Victories', 'Sad', 'Sad', 'Happy', 'Happy', 'Happy',
#        'Sad', 'Sad', 'Victories', 'Sad', 'Sad', 'Sad', 'Victories',
#        'Angry', 'Sad', 'Happy', 'Happy', 'Happy', 'Sad', 'Sad',
#        'Victories', 'Sad', 'Victories', 'Sad', 'Angry', 'Sad', 'Happy',
#        'Happy', 'Sad', 'Sad', 'Sad', 'Sad', 'Victories', 'Happy', 'Happy',
#        'Victories', 'Happy', 'Angry', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Sad', 'Happy', 'Angry', 'Sad', 'Happy', 'Angry', 'Happy', 'Happy',
#        'Angry', 'Angry', 'Happy', 'Sad', 'Sad', 'Sad', 'Victories',
#        'Victories', 'Angry', 'Victories', 'Sad', 'Victories', 'Angry',
#        'Sad', 'Victories', 'Sad', 'Sad', 'Sad', 'Victories', 'Sad',
#        'Angry', 'Sad', 'Victories', 'Victories', 'Angry', 'Sad', 'Happy',
#        'Happy', 'Angry', 'Angry', 'Sad', 'Sad', 'Angry', 'Sad', 'Sad',
#        'Angry', 'Sad', 'Happy', 'Angry', 'Happy', 'Sad', 'Angry', 'Sad',
#        'Happy', 'Victories', 'Angry', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Happy', 'Sad', 'Sad', 'Sad', 'Victories', 'Sad', 'Angry', 'Sad',
#        'Happy', 'Victories', 'Happy', 'Sad', 'Sad', 'Happy', 'Angry',
#        'Angry', 'Angry', 'Happy', 'Sad', 'Angry', 'Happy', 'Sad', 'Angry',
#        'Happy', 'Angry', 'Victories', 'Sad', 'Sad', 'Sad', 'Happy',
#        'Happy', 'Victories', 'Sad', 'Sad', 'Happy', 'Angry', 'Victories',
#        'Sad', 'Angry', 'Sad', 'Sad', 'Sad', 'Victories', 'Angry', 'Angry',
#        'Happy', 'Sad', 'Angry', 'Happy', 'Sad', 'Sad', 'Sad', 'Happy',
#        'Sad', 'Victories', 'Angry', 'Sad', 'Sad', 'Sad', 'Angry',
#        'Victories', 'Sad', 'Sad', 'Sad', 'Happy', 'Angry', 'Happy',
#        'Angry', 'Sad', 'Angry', 'Sad', 'Angry', 'Victories', 'Victories',
#        'Sad', 'Sad', 'Happy', 'Sad', 'Sad', 'Sad', 'Sad'], dtype=object)

# %%
y_test
# Out:
# 1212        Angry
# 1053        Angry
# 1159        Angry
# 281         Happy
# 878     Victories
#           ...
# 155         Happy
# 470           Sad
# 725           Sad
# 685           Sad
# 356           Sad
# Name: class, Length: 382, dtype: object

# %%
with open('body_language.pkl', 'wb') as f:
    pickle.dump(fit_models['rf'], f)
