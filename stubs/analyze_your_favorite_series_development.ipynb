# %% [markdown]
# <a href="https://colab.research.google.com/github/head1ton/Analysis_System/blob/main/stubs/analyze_your_favorite_series_development.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Clone Repo

# %%
# !git clone https://github.com/head1ton/Analysis_System.git
# Out:
# Cloning into 'Analysis_System'...
# remote: Enumerating objects: 257, done.
# remote: Counting objects: 100% (257/257), done.
# remote: Compressing objects: 100% (247/247), done.
# remote: Total 257 (delta 3), reused 252 (delta 1), pack-reused 0 (from 0)
# Receiving objects: 100% (257/257), 2.15 MiB | 9.17 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
# !cd Analysis_System && git pull

# %%
# # requirements.txt
# !pip install transformers
# !pip install huggingface_hub
# !pip install nltk
# !pip install gradio

# %%
# !cd Analysis_System && pip install -r requirements.txt
# Out:
# Collecting aiofiles==23.2.1 (from -r requirements.txt (line 1))
#   Downloading aiofiles-23.2.1-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: annotated-types==0.7.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 2)) (0.7.0)
# Collecting anyio==4.9.0 (from -r requirements.txt (line 3))
#   Downloading anyio-4.9.0-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: attrs==25.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 4)) (25.3.0)
# Collecting Automat==24.8.1 (from -r requirements.txt (line 5))
#   Downloading Automat-24.8.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: beautifulsoup4==4.13.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 6)) (4.13.3)
# Collecting bitsandbytes==0.42.0 (from -r requirements.txt (line 7))
#   Downloading bitsandbytes-0.42.0-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: certifi==2025.1.31 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 8)) (2025.1.31)
# Requirement already satisfied: cffi==1.17.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 9)) (1.17.1)
# Requirement already satisfied: charset-normalizer==3.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 10)) (3.4.1)
# Requirement already satisfied: click==8.1.8 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 11)) (8.1.8)
# Collecting constantly==23.10.4 (from -r requirements.txt (line 12))
#   Downloading constantly-23.10.4-py3-none-any.whl.metadata (1.8 kB)
# Collecting cryptography==44.0.2 (from -r requirements.txt (line 13))
#   Downloading cryptography-44.0.2-cp39-abi3-manylinux_2_34_x86_64.whl.metadata (5.7 kB)
# Collecting cssselect==1.3.0 (from -r requirements.txt (line 14))
#   Downloading cssselect-1.3.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: defusedxml==0.7.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 15)) (0.7.1)
# Collecting fastapi==0.115.11 (from -r requirements.txt (line 16))
#   Downloading fastapi-0.115.11-py3-none-any.whl.metadata (27 kB)
# Collecting ffmpy==0.5.0 (from -r requirements.txt (line 17))
#   Downloading ffmpy-0.5.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting filelock==3.18.0 (from -r requirements.txt (line 18))
#   Downloading filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec==2025.3.0 (from -r requirements.txt (line 19))
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting gradio==5.21.0 (from -r requirements.txt (line 20))
#   Downloading gradio-5.21.0-py3-none-any.whl.metadata (16 kB)
# Collecting gradio_client==1.7.2 (from -r requirements.txt (line 21))
#   Downloading gradio_client-1.7.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting groovy==0.1.2 (from -r requirements.txt (line 22))
#   Downloading groovy-0.1.2-py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: h11==0.14.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 23)) (0.14.0)
# Requirement already satisfied: httpcore==1.0.7 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 24)) (1.0.7)
# Requirement already satisfied: httpx==0.28.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 25)) (0.28.1)
# Collecting huggingface-hub==0.29.3 (from -r requirements.txt (line 26))
#   Downloading huggingface_hub-0.29.3-py3-none-any.whl.metadata (13 kB)
# Collecting hyperlink==21.0.0 (from -r requirements.txt (line 27))
#   Downloading hyperlink-21.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: idna==3.10 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 28)) (3.10)
# Collecting incremental==24.7.2 (from -r requirements.txt (line 29))
#   Downloading incremental-24.7.2-py3-none-any.whl.metadata (8.1 kB)
# Collecting itemadapter==0.11.0 (from -r requirements.txt (line 30))
#   Downloading itemadapter-0.11.0-py3-none-any.whl.metadata (18 kB)
# Collecting itemloaders==1.3.2 (from -r requirements.txt (line 31))
#   Downloading itemloaders-1.3.2-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: Jinja2==3.1.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 32)) (3.1.6)
# Collecting jmespath==1.0.1 (from -r requirements.txt (line 33))
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Requirement already satisfied: joblib==1.4.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 34)) (1.4.2)
# Requirement already satisfied: lxml==5.3.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 35)) (5.3.1)
# Requirement already satisfied: markdown-it-py==3.0.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 36)) (3.0.0)
# Collecting MarkupSafe==2.1.5 (from -r requirements.txt (line 37))
#   Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.0 kB)
# Requirement already satisfied: mdurl==0.1.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 38)) (0.1.2)
# Requirement already satisfied: mpmath==1.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 39)) (1.3.0)
# Requirement already satisfied: networkx==3.4.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 40)) (3.4.2)
# Requirement already satisfied: nltk==3.9.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 41)) (3.9.1)
# Collecting numpy==2.2.4 (from -r requirements.txt (line 42))
#   Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 5.5 MB/s eta 0:00:00
# Requirement already satisfied: orjson==3.10.15 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 43)) (3.10.15)
# Requirement already satisfied: packaging==24.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 44)) (24.2)
# Collecting pandas==2.2.3 (from -r requirements.txt (line 45))
#   Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 8.1 MB/s eta 0:00:00
# Collecting parsel==1.10.0 (from -r requirements.txt (line 46))
#   Downloading parsel-1.10.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow==11.1.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 47)) (11.1.0)
# Collecting Protego==0.4.0 (from -r requirements.txt (line 48))
#   Downloading Protego-0.4.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: pyasn1==0.6.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 49)) (0.6.1)
# Requirement already satisfied: pyasn1_modules==0.4.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 50)) (0.4.1)
# Requirement already satisfied: pycparser==2.22 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 51)) (2.22)
# Requirement already satisfied: pydantic==2.10.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 52)) (2.10.6)
# Requirement already satisfied: pydantic_core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 53)) (2.27.2)
# Collecting PyDispatcher==2.0.7 (from -r requirements.txt (line 54))
#   Downloading PyDispatcher-2.0.7-py3-none-any.whl.metadata (2.4 kB)
# Collecting pydub==0.25.1 (from -r requirements.txt (line 55))
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting Pygments==2.19.1 (from -r requirements.txt (line 56))
#   Downloading pygments-2.19.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting pyOpenSSL==25.0.0 (from -r requirements.txt (line 57))
#   Downloading pyOpenSSL-25.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting python-dateutil==2.9.0.post0 (from -r requirements.txt (line 58))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting python-multipart==0.0.20 (from -r requirements.txt (line 59))
#   Downloading python_multipart-0.0.20-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: pytz==2025.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 60)) (2025.1)
# Requirement already satisfied: PyYAML==6.0.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 61)) (6.0.2)
# Collecting queuelib==1.7.0 (from -r requirements.txt (line 62))
#   Downloading queuelib-1.7.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: regex==2024.11.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 63)) (2024.11.6)
# Requirement already satisfied: requests==2.32.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 64)) (2.32.3)
# Collecting requests-file==2.1.0 (from -r requirements.txt (line 65))
#   Downloading requests_file-2.1.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: rich==13.9.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 66)) (13.9.4)
# Collecting ruff==0.11.0 (from -r requirements.txt (line 67))
#   Downloading ruff-0.11.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Collecting safehttpx==0.1.6 (from -r requirements.txt (line 68))
#   Downloading safehttpx-0.1.6-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: safetensors==0.5.3 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 69)) (0.5.3)
# Collecting scipy==1.15.2 (from -r requirements.txt (line 70))
#   Downloading scipy-1.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 6.1 MB/s eta 0:00:00
# Collecting Scrapy==2.12.0 (from -r requirements.txt (line 71))
#   Downloading Scrapy-2.12.0-py2.py3-none-any.whl.metadata (5.3 kB)
# Collecting semantic-version==2.10.0 (from -r requirements.txt (line 72))
#   Downloading semantic_version-2.10.0-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting service-identity==24.2.0 (from -r requirements.txt (line 73))
#   Downloading service_identity-24.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting setuptools==76.1.0 (from -r requirements.txt (line 74))
#   Downloading setuptools-76.1.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: shellingham==1.5.4 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 75)) (1.5.4)
# Requirement already satisfied: six==1.17.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 76)) (1.17.0)
# Requirement already satisfied: sniffio==1.3.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 77)) (1.3.1)
# Requirement already satisfied: soupsieve==2.6 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 78)) (2.6)
# Collecting starlette==0.46.1 (from -r requirements.txt (line 79))
#   Downloading starlette-0.46.1-py3-none-any.whl.metadata (6.2 kB)
# Collecting sympy==1.13.3 (from -r requirements.txt (line 80))
#   Downloading sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting tldextract==5.1.3 (from -r requirements.txt (line 81))
#   Downloading tldextract-5.1.3-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: tokenizers==0.21.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 82)) (0.21.1)
# Collecting tomlkit==0.13.2 (from -r requirements.txt (line 83))
#   Downloading tomlkit-0.13.2-py3-none-any.whl.metadata (2.7 kB)
# Collecting torch==2.2.2 (from -r requirements.txt (line 84))
#   Downloading torch-2.2.2-cp311-cp311-manylinux1_x86_64.whl.metadata (25 kB)
# Collecting torchvision==0.17.2 (from -r requirements.txt (line 85))
#   Downloading torchvision-0.17.2-cp311-cp311-manylinux1_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: tqdm==4.67.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 86)) (4.67.1)
# Collecting transformers==4.49.0 (from -r requirements.txt (line 87))
#   Downloading transformers-4.49.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.1 MB/s eta 0:00:00
# Collecting Twisted==24.11.0 (from -r requirements.txt (line 88))
#   Downloading twisted-24.11.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: typer==0.15.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 89)) (0.15.2)
# Requirement already satisfied: typing_extensions==4.12.2 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 90)) (4.12.2)
# Requirement already satisfied: tzdata==2025.1 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 91)) (2025.1)
# Requirement already satisfied: urllib3==2.3.0 in /usr/local/lib/python3.11/dist-packages (from -r requirements.txt (line 92)) (2.3.0)
# Collecting uvicorn==0.34.0 (from -r requirements.txt (line 93))
#   Downloading uvicorn-0.34.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting w3lib==2.3.1 (from -r requirements.txt (line 94))
#   Downloading w3lib-2.3.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting websockets==15.0.1 (from -r requirements.txt (line 95))
#   Downloading websockets-15.0.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.8 kB)
# Collecting zope.interface==7.2 (from -r requirements.txt (line 96))
#   Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 3.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.2.2->-r requirements.txt (line 84))
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.2.2->-r requirements.txt (line 84))
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.2.2->-r requirements.txt (line 84))
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.2.2->-r requirements.txt (line 84))
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.2.2->-r requirements.txt (line 84))
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.2.2->-r requirements.txt (line 84))
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.2.2->-r requirements.txt (line 84))
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.2.2->-r requirements.txt (line 84))
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.2.2->-r requirements.txt (line 84))
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch==2.2.2->-r requirements.txt (line 84))
#   Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.2.2->-r requirements.txt (line 84))
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.2.0 (from torch==2.2.2->-r requirements.txt (line 84))
#   Downloading triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.4 kB)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.11/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.2.2->-r requirements.txt (line 84)) (12.5.82)
# Downloading aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Downloading anyio-4.9.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.9/100.9 kB 8.9 MB/s eta 0:00:00
# Downloading Automat-24.8.1-py3-none-any.whl (42 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 3.8 MB/s eta 0:00:00
# Downloading bitsandbytes-0.42.0-py3-none-any.whl (105.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 MB 8.3 MB/s eta 0:00:00
# Downloading constantly-23.10.4-py3-none-any.whl (13 kB)
# Downloading cryptography-44.0.2-cp39-abi3-manylinux_2_34_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 109.1 MB/s eta 0:00:00
# Downloading cssselect-1.3.0-py3-none-any.whl (18 kB)
# Downloading fastapi-0.115.11-py3-none-any.whl (94 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 9.5 MB/s eta 0:00:00
# Downloading ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Downloading filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 17.5 MB/s eta 0:00:00
# Downloading gradio-5.21.0-py3-none-any.whl (46.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 15.1 MB/s eta 0:00:00
# Downloading gradio_client-1.7.2-py3-none-any.whl (322 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.1/322.1 kB 28.0 MB/s eta 0:00:00
# Downloading groovy-0.1.2-py3-none-any.whl (14 kB)
# Downloading huggingface_hub-0.29.3-py3-none-any.whl (468 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 469.0/469.0 kB 39.6 MB/s eta 0:00:00
# Downloading hyperlink-21.0.0-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.6/74.6 kB 7.6 MB/s eta 0:00:00
# Downloading incremental-24.7.2-py3-none-any.whl (20 kB)
# Downloading itemadapter-0.11.0-py3-none-any.whl (11 kB)
# Downloading itemloaders-1.3.2-py3-none-any.whl (12 kB)
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading MarkupSafe-2.1.5-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (28 kB)
# Downloading numpy-2.2.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 104.7 MB/s eta 0:00:00
# Downloading pandas-2.2.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 111.7 MB/s eta 0:00:00
# Downloading parsel-1.10.0-py2.py3-none-any.whl (17 kB)
# Downloading Protego-0.4.0-py2.py3-none-any.whl (8.6 kB)
# Downloading PyDispatcher-2.0.7-py3-none-any.whl (12 kB)
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading pygments-2.19.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 65.5 MB/s eta 0:00:00
# Downloading pyOpenSSL-25.0.0-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 kB 5.4 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.9/229.9 kB 22.1 MB/s eta 0:00:00
# Downloading python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Downloading queuelib-1.7.0-py2.py3-none-any.whl (13 kB)
# Downloading requests_file-2.1.0-py2.py3-none-any.whl (4.2 kB)
# Downloading ruff-0.11.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 120.0 MB/s eta 0:00:00
# Downloading safehttpx-0.1.6-py3-none-any.whl (8.7 kB)
# Downloading scipy-1.15.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.6/37.6 MB 22.9 MB/s eta 0:00:00
# Downloading Scrapy-2.12.0-py2.py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.2/311.2 kB 24.2 MB/s eta 0:00:00
# Downloading semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Downloading service_identity-24.2.0-py3-none-any.whl (11 kB)
# Downloading setuptools-76.1.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 69.5 MB/s eta 0:00:00
# Downloading starlette-0.46.1-py3-none-any.whl (71 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.9 MB/s eta 0:00:00
# Downloading sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 107.2 MB/s eta 0:00:00
# Downloading tldextract-5.1.3-py3-none-any.whl (104 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.9/104.9 kB 10.7 MB/s eta 0:00:00
# Downloading tomlkit-0.13.2-py3-none-any.whl (37 kB)
# Downloading torch-2.2.2-cp311-cp311-manylinux1_x86_64.whl (755.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 MB 1.9 MB/s eta 0:00:00
# Downloading torchvision-0.17.2-cp311-cp311-manylinux1_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 113.1 MB/s eta 0:00:00
# Downloading transformers-4.49.0-py3-none-any.whl (10.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 124.7 MB/s eta 0:00:00
# Downloading twisted-24.11.0-py3-none-any.whl (3.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 89.8 MB/s eta 0:00:00
# Downloading uvicorn-0.34.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 6.2 MB/s eta 0:00:00
# Downloading w3lib-2.3.1-py3-none-any.whl (21 kB)
# Downloading websockets-15.0.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (182 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 182.3/182.3 kB 16.8 MB/s eta 0:00:00
# Downloading zope.interface-7.2-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (259 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.8/259.8 kB 21.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 67.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 59.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 59.5 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 16.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 7.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.6 MB/s eta 0:00:00
# Downloading triton-2.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (167.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 MB 7.8 MB/s eta 0:00:00
# Installing collected packages: pydub, PyDispatcher, websockets, w3lib, uvicorn, tomlkit, sympy, setuptools, semantic-version, ruff, queuelib, python-multipart, python-dateutil, Pygments, Protego, nvidia-nvtx-cu12, nvidia-nccl-cu12, nvidia-cusparse-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, MarkupSafe, jmespath, itemadapter, hyperlink, groovy, fsspec, filelock, ffmpy, cssselect, constantly, Automat, anyio, aiofiles, zope.interface, triton, starlette, scipy, requests-file, parsel, pandas, nvidia-cusolver-cu12, nvidia-cudnn-cu12, incremental, huggingface-hub, cryptography, Twisted, torch, tldextract, service-identity, safehttpx, pyOpenSSL, itemloaders, gradio_client, fastapi, bitsandbytes, transformers, torchvision, Scrapy, gradio
#   Attempting uninstall: websockets
#     Found existing installation: websockets 14.2
#     Uninstalling websockets-14.2:
#       Successfully uninstalled websockets-14.2
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
#   Attempting uninstall: python-dateutil
#     Found existing installation: python-dateutil 2.8.2
#     Uninstalling python-dateutil-2.8.2:
#       Successfully uninstalled python-dateutil-2.8.2
#   Attempting uninstall: Pygments
#     Found existing installation: Pygments 2.18.0
#     Uninstalling Pygments-2.18.0:
#       Successfully uninstalled Pygments-2.18.0
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.21.5
#     Uninstalling nvidia-nccl-cu12-2.21.5:
#       Successfully uninstalled nvidia-nccl-cu12-2.21.5
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 3.0.2
#     Uninstalling MarkupSafe-3.0.2:
#       Successfully uninstalled MarkupSafe-3.0.2
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2024.10.0
#     Uninstalling fsspec-2024.10.0:
#       Successfully uninstalled fsspec-2024.10.0
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.17.0
#     Uninstalling filelock-3.17.0:
#       Successfully uninstalled filelock-3.17.0
#   Attempting uninstall: anyio
#     Found existing installation: anyio 3.7.1
#     Uninstalling anyio-3.7.1:
#       Successfully uninstalled anyio-3.7.1
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.14.1
#     Uninstalling scipy-1.14.1:
#       Successfully uninstalled scipy-1.14.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.28.1
#     Uninstalling huggingface-hub-0.28.1:
#       Successfully uninstalled huggingface-hub-0.28.1
#   Attempting uninstall: cryptography
#     Found existing installation: cryptography 43.0.3
#     Uninstalling cryptography-43.0.3:
#       Successfully uninstalled cryptography-43.0.3
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: pyOpenSSL
#     Found existing installation: pyOpenSSL 24.2.1
#     Uninstalling pyOpenSSL-24.2.1:
#       Successfully uninstalled pyOpenSSL-24.2.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.48.3
#     Uninstalling transformers-4.48.3:
#       Successfully uninstalled transformers-4.48.3
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2025.3.0 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.2.4 which is incompatible.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.2.2 which is incompatible.
# pydrive2 1.21.3 requires cryptography<44, but you have cryptography 44.0.2 which is incompatible.
# pydrive2 1.21.3 requires pyOpenSSL<=24.2.1,>=19.1.0, but you have pyopenssl 25.0.0 which is incompatible.
# google-genai 1.4.0 requires websockets<15.0dev,>=13.0, but you have websockets 15.0.1 which is incompatible.
# jupyter-server 1.24.0 requires anyio<4,>=3.1.0, but you have anyio 4.9.0 which is incompatible.
# tensorflow 2.18.0 requires numpy<2.1.0,>=1.26.0, but you have numpy 2.2.4 which is incompatible.
# Successfully installed Automat-24.8.1 MarkupSafe-2.1.5 Protego-0.4.0 PyDispatcher-2.0.7 Pygments-2.19.1 Scrapy-2.12.0 Twisted-24.11.0 aiofiles-23.2.1 anyio-4.9.0 bitsandbytes-0.42.0 constantly-23.10.4 cryptography-44.0.2 cssselect-1.3.0 fastapi-0.115.11 ffmpy-0.5.0 filelock-3.18.0 fsspec-2025.3.0 gradio-5.21.0 gradio_client-1.7.2 groovy-0.1.2 huggingface-hub-0.29.3 hyperlink-21.0.0 incremental-24.7.2 itemadapter-0.11.0 itemloaders-1.3.2 jmespath-1.0.1 numpy-2.2.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvtx-cu12-12.1.105 pandas-2.2.3 parsel-1.10.0 pyOpenSSL-25.0.0 pydub-0.25.1 python-dateutil-2.9.0.post0 python-multipart-0.0.20 queuelib-1.7.0 requests-file-2.1.0 ruff-0.11.0 safehttpx-0.1.6 scipy-1.15.2 semantic-version-2.10.0 service-identity-24.2.0 setuptools-76.1.0 starlette-0.46.1 sympy-1.13.3 tldextract-5.1.3 tomlkit-0.13.2 torch-2.2.2 torchvision-0.17.2 transformers-4.49.0 triton-2.2.0 uvicorn-0.34.0 w3lib-2.3.1 websockets-15.0.1 zope.interface-7.2

# %%
# torch 때문이니 위에 requirements.txt 를 실행한게 아니라면 필요없음
# !pip install 'numpy<2'
# Out:
# Collecting numpy<2
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.2 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 96.0 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.2.4
#     Uninstalling numpy-2.2.4:
#       Successfully uninstalled numpy-2.2.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# Successfully installed numpy-1.26.4

# %% [markdown]
# ### Run app

# %%
# !cd Analysis_System && python gradio_app.py
# Out:
# 2025-03-18 17:29:31.300754: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742318971.321168    2987 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742318971.327664    2987 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-18 17:29:31.349620: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://06e3155f33ef7cc54d.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# Device set to use cuda:0
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
